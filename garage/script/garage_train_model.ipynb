# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
pd.set_option('display.max_columns', None)

# %%
Data = pd.read_csv('../data/garage_data.csv')

# %%
Data
# Out:
#       S.no   Lead Id Initial       Name                       Location  \
# 0     4455  47371519       A    Alaisah               Chippenham, SN14
# 1     4872  47356045       K        Kim                Rayleigh, Essex
# 2     5462  47332808       I       Iwan             Rhosgoch, Anglesey
# 3     1173  47483088       R     Rezwan               Northampton, NN5
# 4     1222  47481389       D    Deborah                  Belfast, BT16
# ..     ...       ...     ...        ...                            ...
# 249  19641  46924919       T     Trevor  Attenborough, Nottinghamshire
# 250  19647  46924433       N  Nathanael             Bognor Regis, PO21
# 251  19698  46920793       N      Nikki              , Gateshead, NE10
# 252  19700  46920672       B        Bob            Littlehampton, BN16
# 253  19726  46918511       R       Ryan             Thame, Oxfordshire
#
#         Time                            Badge 1  \
# 0     4d ago            Urgent badge iconUrgent
# 1     6d ago  Verified badge iconVerified phone
# 2     1w ago  Verified badge iconVerified phone
# 3     3d ago            Urgent badge iconUrgent
# 4     3d ago  Verified badge iconVerified phone
# ..       ...                                ...
# 249  16h ago  Verified badge iconVerified phone
# 250   1w ago  Verified badge iconVerified phone
# 251   1w ago  Verified badge iconVerified phone
# 252   1w ago            Urgent badge iconUrgent
# 253   1w ago  Verified badge iconVerified phone
#
#                                              Badge 2  \
# 0                  Verified badge iconVerified phone
# 1    Additional details badge iconAdditional details
# 2    Additional details badge iconAdditional details
# 3                  Verified badge iconVerified phone
# 4                                                NaN
# ..                                               ...
# 249  Additional details badge iconAdditional details
# 250  Additional details badge iconAdditional details
# 251  Additional details badge iconAdditional details
# 252                Verified badge iconVerified phone
# 253  Additional details badge iconAdditional details
#
#                                              Badge 3  \
# 0    Additional details badge iconAdditional details
# 1              Frequent user badge iconFrequent user
# 2                                                NaN
# 3    Additional details badge iconAdditional details
# 4                                                NaN
# ..                                               ...
# 249                                              NaN
# 250                                              NaN
# 251                                              NaN
# 252  Additional details badge iconAdditional details
# 253            Frequent user badge iconFrequent user
#
#                                    Badge 4            Category  \
# 0    Frequent user badge iconFrequent user  Garage Conversions
# 1                                      NaN  Garage Conversions
# 2                                      NaN  Garage Conversions
# 3                                      NaN  Garage Conversions
# 4                                      NaN  Garage Conversions
# ..                                     ...                 ...
# 249                                    NaN  Garage Conversions
# 250                                    NaN  Garage Conversions
# 251                                    NaN  Garage Conversions
# 252  Frequent user badge iconFrequent user  Garage Conversions
# 253                                    NaN  Garage Conversions
#
#                                                Que/Ans  Credits  \
# 0    Where is the existing garage located? Resident...       11
# 1    Where is the existing garage located? Resident...       11
# 2    Where is the existing garage located? Resident...       11
# 3    Where is the existing garage located? Resident...       10
# 4    Where is the existing garage located? Resident...       10
# ..                                                 ...      ...
# 249  Where is the existing garage located? Resident...        7
# 250  Where is the existing garage located? Resident...        7
# 251  Where is the existing garage located? Resident...        7
# 252  Where is the existing garage located? Resident...        7
# 253  Where is the existing garage located? Resident...        7
#
#            Response  Country  Urgent  High  Verified  Additional  Frequent
# 0        2 out of 5      NaN       1     0         1           1         1
# 1        2 out of 5      NaN       0     0         1           1         1
# 2        1 out of 5      NaN       0     0         1           1         0
# 3            02,May      NaN       1     0         1           1         0
# 4            01,May      NaN       0     0         1           0         0
# ..              ...      ...     ...   ...       ...         ...       ...
# 249  1st to respond      NaN       0     0         1           1         0
# 250      2 out of 5      NaN       0     0         1           1         0
# 251      1 out of 5      NaN       0     0         1           1         0
# 252      4 out of 5      NaN       1     0         1           1         1
# 253      2 out of 5      NaN       0     0         1           1         1
#
# [254 rows x 20 columns]

# %%
Data_F = Data.copy()

# %%
Data_F
# Out:
#       S.no   Lead Id Initial       Name                       Location  \
# 0     4455  47371519       A    Alaisah               Chippenham, SN14
# 1     4872  47356045       K        Kim                Rayleigh, Essex
# 2     5462  47332808       I       Iwan             Rhosgoch, Anglesey
# 3     1173  47483088       R     Rezwan               Northampton, NN5
# 4     1222  47481389       D    Deborah                  Belfast, BT16
# ..     ...       ...     ...        ...                            ...
# 249  19641  46924919       T     Trevor  Attenborough, Nottinghamshire
# 250  19647  46924433       N  Nathanael             Bognor Regis, PO21
# 251  19698  46920793       N      Nikki              , Gateshead, NE10
# 252  19700  46920672       B        Bob            Littlehampton, BN16
# 253  19726  46918511       R       Ryan             Thame, Oxfordshire
#
#         Time                            Badge 1  \
# 0     4d ago            Urgent badge iconUrgent
# 1     6d ago  Verified badge iconVerified phone
# 2     1w ago  Verified badge iconVerified phone
# 3     3d ago            Urgent badge iconUrgent
# 4     3d ago  Verified badge iconVerified phone
# ..       ...                                ...
# 249  16h ago  Verified badge iconVerified phone
# 250   1w ago  Verified badge iconVerified phone
# 251   1w ago  Verified badge iconVerified phone
# 252   1w ago            Urgent badge iconUrgent
# 253   1w ago  Verified badge iconVerified phone
#
#                                              Badge 2  \
# 0                  Verified badge iconVerified phone
# 1    Additional details badge iconAdditional details
# 2    Additional details badge iconAdditional details
# 3                  Verified badge iconVerified phone
# 4                                                NaN
# ..                                               ...
# 249  Additional details badge iconAdditional details
# 250  Additional details badge iconAdditional details
# 251  Additional details badge iconAdditional details
# 252                Verified badge iconVerified phone
# 253  Additional details badge iconAdditional details
#
#                                              Badge 3  \
# 0    Additional details badge iconAdditional details
# 1              Frequent user badge iconFrequent user
# 2                                                NaN
# 3    Additional details badge iconAdditional details
# 4                                                NaN
# ..                                               ...
# 249                                              NaN
# 250                                              NaN
# 251                                              NaN
# 252  Additional details badge iconAdditional details
# 253            Frequent user badge iconFrequent user
#
#                                    Badge 4            Category  \
# 0    Frequent user badge iconFrequent user  Garage Conversions
# 1                                      NaN  Garage Conversions
# 2                                      NaN  Garage Conversions
# 3                                      NaN  Garage Conversions
# 4                                      NaN  Garage Conversions
# ..                                     ...                 ...
# 249                                    NaN  Garage Conversions
# 250                                    NaN  Garage Conversions
# 251                                    NaN  Garage Conversions
# 252  Frequent user badge iconFrequent user  Garage Conversions
# 253                                    NaN  Garage Conversions
#
#                                                Que/Ans  Credits  \
# 0    Where is the existing garage located? Resident...       11
# 1    Where is the existing garage located? Resident...       11
# 2    Where is the existing garage located? Resident...       11
# 3    Where is the existing garage located? Resident...       10
# 4    Where is the existing garage located? Resident...       10
# ..                                                 ...      ...
# 249  Where is the existing garage located? Resident...        7
# 250  Where is the existing garage located? Resident...        7
# 251  Where is the existing garage located? Resident...        7
# 252  Where is the existing garage located? Resident...        7
# 253  Where is the existing garage located? Resident...        7
#
#            Response  Country  Urgent  High  Verified  Additional  Frequent
# 0        2 out of 5      NaN       1     0         1           1         1
# 1        2 out of 5      NaN       0     0         1           1         1
# 2        1 out of 5      NaN       0     0         1           1         0
# 3            02,May      NaN       1     0         1           1         0
# 4            01,May      NaN       0     0         1           0         0
# ..              ...      ...     ...   ...       ...         ...       ...
# 249  1st to respond      NaN       0     0         1           1         0
# 250      2 out of 5      NaN       0     0         1           1         0
# 251      1 out of 5      NaN       0     0         1           1         0
# 252      4 out of 5      NaN       1     0         1           1         1
# 253      2 out of 5      NaN       0     0         1           1         1
#
# [254 rows x 20 columns]

# %%
import pandas as pd
import re

# Assuming your DataFrame is already loaded and has the column 'Que/Ans'
# Example: Data = pd.read_csv('your_file.csv')

# Define all possible question patterns and their desired column headers
questions = {
    "Where is the existing garage located\\?": "Where is the existing garage located?",
    "How big is the garage to be converted\\?": "How big is the garage to be converted?",
    "What are you planning to use the converted garage for\\?": "What are you planning to use the converted garage for?",
    "Do you have plans drawn up\\?": "Do you have plans drawn up?",
    "What is the planning permission status for this job\\?": "What is the planning permission status for this job?",
     "How likely are you to make a hiring decision\\?": "How likely are you to make a hiring decision?"

}

# Function to extract answers for each row
def extract_answers(row):
    extracted = {v: None for v in questions.values()}
    pattern = "(" + "|".join(questions.keys()) + ")"
    parts = re.split(pattern, row)

    i = 1
    while i < len(parts) - 1:
        q = parts[i].strip()
        a = parts[i + 1].strip()
        for k, v in questions.items():
            if re.fullmatch(k, q):
                if extracted[v] is None:
                    extracted[v] = a
                elif v == "Additional Details":
                    # Append multiple Additional Details if present
                    extracted[v] += " | " + a
        i += 2

    return pd.Series(extracted)

# Apply the function to your DataFrame
result_df = Data['Que/Ans'].apply(extract_answers)

# Clean encoding artifacts (like Â, â€¦, etc.)
result_df = result_df.replace({r'[^\x00-\x7F]+': ''}, regex=True)

# Preview the cleaned DataFrame
result_df.head()

# Optional: Save to Excel or CSV
# result_df.to_csv('cleaned_landscaping_data.csv', index=False)
# result_df.to_excel('cleaned_landscaping_data.xlsx', index=False)
# Out:
#     Where is the existing garage located?  \
# 0  Residential  attached to main property
# 1  Residential  attached to main property
# 2    Residential  away from main property
# 3  Residential  attached to main property
# 4  Residential  attached to main property
#
#   How big is the garage to be converted?  \
# 0               Garage that fits one car
# 1               Garage that fits one car
# 2               Garage that fits one car
# 3               Garage that fits one car
# 4               Garage that fits one car
#
#   What are you planning to use the converted garage for?  \
# 0                                        Home office
# 1                                        Home office
# 2                       Self contained accommodation
# 3                                       Living space
# 4                                       Living space
#
#   Do you have plans drawn up?  \
# 0           Yes, I have plans
# 1           Yes, I have plans
# 2           Yes, I have plans
# 3  No, I don't have plans yet
# 4  No, I don't have plans yet
#
#   What is the planning permission status for this job?  \
# 0                        Planning permission granted
# 1                       No planning application made
# 2                        Planning permission granted
# 3                   Planning permission not required
# 4                   Planning permission not required
#
#        How likely are you to make a hiring decision?
# 0  I'm ready to hire  Additional details Converti...
# 1  I'm ready to hire  Additional details Ready  A...
# 2  I'm ready to hire  Additional details Sprinckl...
# 3  I'm ready to hire  Additional details Looking ...
# 4                                  I'm ready to hire

# %%
Data = pd.concat([Data, result_df], axis=1)

# %%
Data
# Out:
#       S.no   Lead Id Initial       Name                       Location  \
# 0     4455  47371519       A    Alaisah               Chippenham, SN14
# 1     4872  47356045       K        Kim                Rayleigh, Essex
# 2     5462  47332808       I       Iwan             Rhosgoch, Anglesey
# 3     1173  47483088       R     Rezwan               Northampton, NN5
# 4     1222  47481389       D    Deborah                  Belfast, BT16
# ..     ...       ...     ...        ...                            ...
# 249  19641  46924919       T     Trevor  Attenborough, Nottinghamshire
# 250  19647  46924433       N  Nathanael             Bognor Regis, PO21
# 251  19698  46920793       N      Nikki              , Gateshead, NE10
# 252  19700  46920672       B        Bob            Littlehampton, BN16
# 253  19726  46918511       R       Ryan             Thame, Oxfordshire
#
#         Time                            Badge 1  \
# 0     4d ago            Urgent badge iconUrgent
# 1     6d ago  Verified badge iconVerified phone
# 2     1w ago  Verified badge iconVerified phone
# 3     3d ago            Urgent badge iconUrgent
# 4     3d ago  Verified badge iconVerified phone
# ..       ...                                ...
# 249  16h ago  Verified badge iconVerified phone
# 250   1w ago  Verified badge iconVerified phone
# 251   1w ago  Verified badge iconVerified phone
# 252   1w ago            Urgent badge iconUrgent
# 253   1w ago  Verified badge iconVerified phone
#
#                                              Badge 2  \
# 0                  Verified badge iconVerified phone
# 1    Additional details badge iconAdditional details
# 2    Additional details badge iconAdditional details
# 3                  Verified badge iconVerified phone
# 4                                                NaN
# ..                                               ...
# 249  Additional details badge iconAdditional details
# 250  Additional details badge iconAdditional details
# 251  Additional details badge iconAdditional details
# 252                Verified badge iconVerified phone
# 253  Additional details badge iconAdditional details
#
#                                              Badge 3  \
# 0    Additional details badge iconAdditional details
# 1              Frequent user badge iconFrequent user
# 2                                                NaN
# 3    Additional details badge iconAdditional details
# 4                                                NaN
# ..                                               ...
# 249                                              NaN
# 250                                              NaN
# 251                                              NaN
# 252  Additional details badge iconAdditional details
# 253            Frequent user badge iconFrequent user
#
#                                    Badge 4            Category  \
# 0    Frequent user badge iconFrequent user  Garage Conversions
# 1                                      NaN  Garage Conversions
# 2                                      NaN  Garage Conversions
# 3                                      NaN  Garage Conversions
# 4                                      NaN  Garage Conversions
# ..                                     ...                 ...
# 249                                    NaN  Garage Conversions
# 250                                    NaN  Garage Conversions
# 251                                    NaN  Garage Conversions
# 252  Frequent user badge iconFrequent user  Garage Conversions
# 253                                    NaN  Garage Conversions
#
#                                                Que/Ans  Credits  \
# 0    Where is the existing garage located? Resident...       11
# 1    Where is the existing garage located? Resident...       11
# 2    Where is the existing garage located? Resident...       11
# 3    Where is the existing garage located? Resident...       10
# 4    Where is the existing garage located? Resident...       10
# ..                                                 ...      ...
# 249  Where is the existing garage located? Resident...        7
# 250  Where is the existing garage located? Resident...        7
# 251  Where is the existing garage located? Resident...        7
# 252  Where is the existing garage located? Resident...        7
# 253  Where is the existing garage located? Resident...        7
#
#            Response  Country  Urgent  High  Verified  Additional  Frequent  \
# 0        2 out of 5      NaN       1     0         1           1         1
# 1        2 out of 5      NaN       0     0         1           1         1
# 2        1 out of 5      NaN       0     0         1           1         0
# 3            02,May      NaN       1     0         1           1         0
# 4            01,May      NaN       0     0         1           0         0
# ..              ...      ...     ...   ...       ...         ...       ...
# 249  1st to respond      NaN       0     0         1           1         0
# 250      2 out of 5      NaN       0     0         1           1         0
# 251      1 out of 5      NaN       0     0         1           1         0
# 252      4 out of 5      NaN       1     0         1           1         1
# 253      2 out of 5      NaN       0     0         1           1         1
#
#       Where is the existing garage located?  \
# 0    Residential  attached to main property
# 1    Residential  attached to main property
# 2      Residential  away from main property
# 3    Residential  attached to main property
# 4    Residential  attached to main property
# ..                                      ...
# 249  Residential  attached to main property
# 250      Residential  next to main property
# 251  Residential  attached to main property
# 252      Residential  next to main property
# 253  Residential  attached to main property
#
#     How big is the garage to be converted?  \
# 0                 Garage that fits one car
# 1                 Garage that fits one car
# 2                 Garage that fits one car
# 3                 Garage that fits one car
# 4                 Garage that fits one car
# ..                                     ...
# 249               Garage that fits one car
# 250               Garage that fits one car
# 251               Garage that fits one car
# 252               Garage that fits one car
# 253               Garage that fits one car
#
#     What are you planning to use the converted garage for?  \
# 0                                          Home office
# 1                                          Home office
# 2                         Self contained accommodation
# 3                                         Living space
# 4                                         Living space
# ..                                                 ...
# 249                                            Storage
# 250                                        Home office
# 251                                            Kitchen
# 252                                       Living space
# 253                                       Utility room
#
#                     Do you have plans drawn up?  \
# 0                             Yes, I have plans
# 1                             Yes, I have plans
# 2                             Yes, I have plans
# 3                    No, I don't have plans yet
# 4                    No, I don't have plans yet
# ..                                          ...
# 249                  No, I don't have plans yet
# 250                  No, I don't have plans yet
# 251                  No, I don't have plans yet
# 252  I would like the pro to help me with plans
# 253                  No, I don't have plans yet
#
#     What is the planning permission status for this job?  \
# 0                          Planning permission granted
# 1                         No planning application made
# 2                          Planning permission granted
# 3                     Planning permission not required
# 4                     Planning permission not required
# ..                                                 ...
# 249                   Planning permission not required
# 250       Planning application made but not determined
# 251          I would like to discuss this with the pro
# 252          I would like to discuss this with the pro
# 253                   Planning permission not required
#
#          How likely are you to make a hiring decision?
# 0    I'm ready to hire  Additional details Converti...
# 1    I'm ready to hire  Additional details Ready  A...
# 2    I'm ready to hire  Additional details Sprinckl...
# 3    I'm ready to hire  Additional details Looking ...
# 4                                    I'm ready to hire
# ..                                                 ...
# 249                       I'm planning and researching
# 250  I'm planning and researching  Additional detai...
# 251  I'm planning and researching  Additional detai...
# 252  I'm planning and researching  Additional detai...
# 253  I'm planning and researching  Additional detai...
#
# [254 rows x 26 columns]

# %%
columns_to_drop = ['S.no', 'Lead Id', 'Response','Country','Additional Details',
    'Initial', 'Name','Time', 'Badge 1','Additional',
    'Badge 2', 'Badge 3', 'Badge 4', 'Category', 'Que/Ans'
]

# Drop the columns (if they exist in the DataFrame)
Data = Data.drop(columns=[col for col in columns_to_drop if col in Data.columns])

# %%
Data.columns
# Out:
# Index(['Location', 'Credits', 'Urgent', 'High', 'Verified', 'Frequent',
#        'Where is the existing garage located?',
#        'How big is the garage to be converted?',
#        'What are you planning to use the converted garage for?',
#        'Do you have plans drawn up?',
#        'What is the planning permission status for this job?',
#        'How likely are you to make a hiring decision?'],
#       dtype='object')

# %%
# Load dataset
df = Data

# Define target variable
target = "Credits"

# Define features
features = [
   'Location','Urgent', 'High', 'Verified', 'Frequent',
       'Where is the existing garage located?',
       'How big is the garage to be converted?',
       'What are you planning to use the converted garage for?',
       'Do you have plans drawn up?',
       'What is the planning permission status for this job?',
       'How likely are you to make a hiring decision?']

# %%
# Drop rows with missing target values
df = df.dropna(subset=[target])

# %%
# Identify categorical and numerical features
cat_features = df[features].select_dtypes(include=['object']).columns.tolist()
num_features = df[features].select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
# Fill missing values
df[cat_features] = df[cat_features].fillna("Unknown")
df[num_features] = df[num_features].fillna(df[num_features].median())

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Convert to CatBoost Pool format
train_pool = Pool(X_train, label=y_train, cat_features=cat_features)
test_pool = Pool(X_test, label=y_test, cat_features=cat_features)

# %%
# Initialize CatBoost model
model = CatBoostRegressor(
    iterations=500,
    learning_rate=0.05,
    depth=8,
    loss_function='RMSE',
    cat_features=cat_features,
    verbose=100
)

# %%
# Train model
model.fit(train_pool, eval_set=test_pool, early_stopping_rounds=50)
# Out:
# 0:	learn: 1.0740614	test: 1.2112638	best: 1.2112638 (0)	total: 207ms	remaining: 1m 43s
# 100:	learn: 0.5902181	test: 1.0092592	best: 1.0074564 (97)	total: 4.21s	remaining: 16.7s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.007456436
# bestIteration = 97
#
# Shrink model to first 98 iterations.

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate model
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# %%
print(f"RMSE: {rmse}")
print(f"R2 Score: {r2}")
# Out:
# RMSE: 1.0074564360502358
# R2 Score: 0.31890273687511594

# %%
validated = df[features]

# %%
# Make predictions on NewData without specifying cat_features
NewDataPrediction = model.predict(df[features])

# %%
import catboost
import numpy as np
import pandas as pd

# Get SHAP values, including the base value, for all records in NewData
shap_values = model.get_feature_importance(
    data=catboost.Pool(validated, cat_features=cat_features),
    type="ShapValues"
)

# Get predicted values
predicted_values = model.predict(validated)

# Convert SHAP values to DataFrame (include base value)
shap_columns = list(validated.columns) + ["base_value"]
shap_df = pd.DataFrame(shap_values, columns=shap_columns)

# Add predicted values column
shap_df["predicted_value"] = predicted_values

# Display SHAP values with predictions
shap_df  # Show SHAP values for the first few records including prediction
# Out:
#      Location    Urgent      High  Verified  Frequent  \
# 0         0.0  0.121829 -0.054452  0.006842  0.010286
# 1         0.0 -0.052216 -0.083539  0.004576  0.013408
# 2         0.0 -0.041785 -0.076145  0.005821  0.000079
# 3         0.0  0.313403 -0.069095  0.009200  0.004426
# 4         0.0 -0.082174 -0.093004  0.006983  0.004426
# ..        ...       ...       ...       ...       ...
# 249       0.0 -0.114204 -0.094904  0.003130 -0.006707
# 250       0.0 -0.100119 -0.093926  0.005220 -0.007721
# 251       0.0 -0.116796 -0.111732  0.004865 -0.008394
# 252       0.0  0.379908 -0.084815  0.005735  0.003380
# 253       0.0 -0.110422 -0.094640  0.004116 -0.005558
#
#      Where is the existing garage located?  \
# 0                                 0.086154
# 1                                 0.053718
# 2                                 0.111855
# 3                                 0.052984
# 4                                -0.005901
# ..                                     ...
# 249                              -0.058827
# 250                              -0.033332
# 251                              -0.029192
# 252                              -0.006778
# 253                              -0.061976
#
#      How big is the garage to be converted?  \
# 0                                  0.121808
# 1                                  0.125312
# 2                                  0.107138
# 3                                  0.107223
# 4                                  0.075008
# ..                                      ...
# 249                               -0.017857
# 250                               -0.002746
# 251                               -0.012272
# 252                                0.049440
# 253                               -0.017588
#
#      What are you planning to use the converted garage for?  \
# 0                                             0.145073
# 1                                             0.127529
# 2                                             0.090682
# 3                                             0.154152
# 4                                             0.170085
# ..                                                 ...
# 249                                          -0.042095
# 250                                          -0.011570
# 251                                           0.000126
# 252                                           0.059599
# 253                                          -0.016304
#
#      Do you have plans drawn up?  \
# 0                       0.703912
# 1                       0.955880
# 2                       0.857742
# 3                       0.006307
# 4                       0.061319
# ..                           ...
# 249                    -0.186182
# 250                    -0.165926
# 251                    -0.145750
# 252                    -0.171350
# 253                    -0.162565
#
#      What is the planning permission status for this job?  \
# 0                                             0.105851
# 1                                             0.071016
# 2                                             0.142806
# 3                                             0.080480
# 4                                             0.064210
# ..                                                 ...
# 249                                          -0.012236
# 250                                           0.080622
# 251                                          -0.038848
# 252                                          -0.013133
# 253                                          -0.008619
#
#      How likely are you to make a hiring decision?  base_value  \
# 0                                         0.024080    7.995345
# 1                                         0.079638    7.995345
# 2                                         0.057321    7.995345
# 3                                         0.176314    7.995345
# 4                                         0.312722    7.995345
# ..                                             ...         ...
# 249                                      -0.494722    7.995345
# 250                                      -0.351115    7.995345
# 251                                       0.073641    7.995345
# 252                                      -0.387626    7.995345
# 253                                      -0.402614    7.995345
#
#      predicted_value
# 0           9.266727
# 1           9.290666
# 2           9.250860
# 3           8.830740
# 4           8.509018
# ..               ...
# 249         6.970741
# 250         7.314732
# 251         7.610993
# 252         7.829705
# 253         7.119175
#
# [254 rows x 13 columns]

# %%
shap_df1 = shap_df.merge(Data_F[["Credits","Lead Id"]], left_index=True, right_index=True)

# %%
shap_df1
# Out:
#      Location    Urgent      High  Verified  Frequent  \
# 0         0.0  0.121829 -0.054452  0.006842  0.010286
# 1         0.0 -0.052216 -0.083539  0.004576  0.013408
# 2         0.0 -0.041785 -0.076145  0.005821  0.000079
# 3         0.0  0.313403 -0.069095  0.009200  0.004426
# 4         0.0 -0.082174 -0.093004  0.006983  0.004426
# ..        ...       ...       ...       ...       ...
# 249       0.0 -0.114204 -0.094904  0.003130 -0.006707
# 250       0.0 -0.100119 -0.093926  0.005220 -0.007721
# 251       0.0 -0.116796 -0.111732  0.004865 -0.008394
# 252       0.0  0.379908 -0.084815  0.005735  0.003380
# 253       0.0 -0.110422 -0.094640  0.004116 -0.005558
#
#      Where is the existing garage located?  \
# 0                                 0.086154
# 1                                 0.053718
# 2                                 0.111855
# 3                                 0.052984
# 4                                -0.005901
# ..                                     ...
# 249                              -0.058827
# 250                              -0.033332
# 251                              -0.029192
# 252                              -0.006778
# 253                              -0.061976
#
#      How big is the garage to be converted?  \
# 0                                  0.121808
# 1                                  0.125312
# 2                                  0.107138
# 3                                  0.107223
# 4                                  0.075008
# ..                                      ...
# 249                               -0.017857
# 250                               -0.002746
# 251                               -0.012272
# 252                                0.049440
# 253                               -0.017588
#
#      What are you planning to use the converted garage for?  \
# 0                                             0.145073
# 1                                             0.127529
# 2                                             0.090682
# 3                                             0.154152
# 4                                             0.170085
# ..                                                 ...
# 249                                          -0.042095
# 250                                          -0.011570
# 251                                           0.000126
# 252                                           0.059599
# 253                                          -0.016304
#
#      Do you have plans drawn up?  \
# 0                       0.703912
# 1                       0.955880
# 2                       0.857742
# 3                       0.006307
# 4                       0.061319
# ..                           ...
# 249                    -0.186182
# 250                    -0.165926
# 251                    -0.145750
# 252                    -0.171350
# 253                    -0.162565
#
#      What is the planning permission status for this job?  \
# 0                                             0.105851
# 1                                             0.071016
# 2                                             0.142806
# 3                                             0.080480
# 4                                             0.064210
# ..                                                 ...
# 249                                          -0.012236
# 250                                           0.080622
# 251                                          -0.038848
# 252                                          -0.013133
# 253                                          -0.008619
#
#      How likely are you to make a hiring decision?  base_value  \
# 0                                         0.024080    7.995345
# 1                                         0.079638    7.995345
# 2                                         0.057321    7.995345
# 3                                         0.176314    7.995345
# 4                                         0.312722    7.995345
# ..                                             ...         ...
# 249                                      -0.494722    7.995345
# 250                                      -0.351115    7.995345
# 251                                       0.073641    7.995345
# 252                                      -0.387626    7.995345
# 253                                      -0.402614    7.995345
#
#      predicted_value  Credits   Lead Id
# 0           9.266727       11  47371519
# 1           9.290666       11  47356045
# 2           9.250860       11  47332808
# 3           8.830740       10  47483088
# 4           8.509018       10  47481389
# ..               ...      ...       ...
# 249         6.970741        7  46924919
# 250         7.314732        7  46924433
# 251         7.610993        7  46920793
# 252         7.829705        7  46920672
# 253         7.119175        7  46918511
#
# [254 rows x 15 columns]

# %%
shap_df1.to_csv("../data/garage_scores.csv", index=False)

# %%
# Save model
joblib.dump(model, "../model/garage_model_2.pkl")

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
# Save the filtered dataset
#df_results.to_csv("Scores_Actual_vs_Predicted.csv", index=False)
