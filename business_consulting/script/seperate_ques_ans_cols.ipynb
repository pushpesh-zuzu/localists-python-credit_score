# %%
import pandas as pd
import numpy as np

from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import joblib

pd.set_option('display.max_columns', None)
Data = pd.read_csv('../data/data_with_merged_cols_business_consulting.csv')
Data
# Out:
#                        Location     Time             Category  \
# 0      Kegworth, Leicestershire   1w ago  Business Consulting
# 1                   London, TW9   1w ago  Business Consulting
# 2                   London, KT3   1w ago  Business Consulting
# 3                Sheffield, S13   1w ago  Business Consulting
# 4                  Cobham, KT11   1w ago  Business Consulting
# ..                          ...      ...                  ...
# 382  Kensington, Greater London   1d ago  Business Consulting
# 383              , Wembley, HA9   1d ago  Business Consulting
# 384            Broxbourne, EN10  22h ago  Business Consulting
# 385              Rotherham, S65  18h ago  Business Consulting
# 386      , Great Shelford, CB22  18h ago  Business Consulting
#
#                                                Que/Ans  Urgent  High  \
# 0    Have you used business consulting services bef...       0     0
# 1    Have you used business consulting services bef...       1     0
# 2    Have you used business consulting services bef...       1     0
# 3    Have you used business consulting services bef...       1     0
# 4    Have you used business consulting services bef...       0     0
# ..                                                 ...     ...   ...
# 382  Have you used business consulting services bef...       0     0
# 383  Have you used business consulting services bef...       1     0
# 384  Have you used business consulting services bef...       0     0
# 385  Have you used business consulting services bef...       0     0
# 386  Have you used business consulting services bef...       1     0
#
#      Verified  Additional  Frequent
# 0           1           1         0
# 1           1           1         0
# 2           0           1         0
# 3           1           1         0
# 4           1           1         1
# ..        ...         ...       ...
# 382         1           0         1
# 383         1           1         0
# 384         0           0         1
# 385         1           0         0
# 386         1           1         0
#
# [387 rows x 9 columns]

# %%
Data_F = Data.copy()
Data_F
# Out:
#                        Location     Time             Category  \
# 0      Kegworth, Leicestershire   1w ago  Business Consulting
# 1                   London, TW9   1w ago  Business Consulting
# 2                   London, KT3   1w ago  Business Consulting
# 3                Sheffield, S13   1w ago  Business Consulting
# 4                  Cobham, KT11   1w ago  Business Consulting
# ..                          ...      ...                  ...
# 382  Kensington, Greater London   1d ago  Business Consulting
# 383              , Wembley, HA9   1d ago  Business Consulting
# 384            Broxbourne, EN10  22h ago  Business Consulting
# 385              Rotherham, S65  18h ago  Business Consulting
# 386      , Great Shelford, CB22  18h ago  Business Consulting
#
#                                                Que/Ans  Urgent  High  \
# 0    Have you used business consulting services bef...       0     0
# 1    Have you used business consulting services bef...       1     0
# 2    Have you used business consulting services bef...       1     0
# 3    Have you used business consulting services bef...       1     0
# 4    Have you used business consulting services bef...       0     0
# ..                                                 ...     ...   ...
# 382  Have you used business consulting services bef...       0     0
# 383  Have you used business consulting services bef...       1     0
# 384  Have you used business consulting services bef...       0     0
# 385  Have you used business consulting services bef...       0     0
# 386  Have you used business consulting services bef...       1     0
#
#      Verified  Additional  Frequent
# 0           1           1         0
# 1           1           1         0
# 2           0           1         0
# 3           1           1         0
# 4           1           1         1
# ..        ...         ...       ...
# 382         1           0         1
# 383         1           1         0
# 384         0           0         1
# 385         1           0         0
# 386         1           1         0
#
# [387 rows x 9 columns]

# %%
import re

# Define all possible question patterns and their desired column headers
questions = {
    "Have you used business consulting services before\\?": "Have you used business consulting services before?",
    "How long has the business been running\\?": "How long has the business been running?",
    "What is the business's annual turnover/sales\\?": "What is the business annual turnover/sales?",
    "How many employees do you have\\?": "How many employees do you have?",
    "What industry is your business in\\?": "What industry is your business in?",
    "Which type\\(s\\) of consulting are you interested in\\?": "Which type(s) of consulting are you interested in?",
    "What are your goals for this service\\?": "What are your goals for this service?",
    "How long do you need a consultant\\?": "How long do you need a consultant?",
    "How would you like to work with the consultant\\?": "How would you like to work with the consultant?",

}

# Function to extract answers for each row
def extract_answers(row):
    extracted = {v: None for v in questions.values()}
    pattern = "(" + "|".join(questions.keys()) + ")"
    parts = re.split(pattern, row)

    i = 1
    while i < len(parts) - 1:
        q = parts[i].strip()
        a = parts[i + 1].strip()
        for k, v in questions.items():
            if re.fullmatch(k, q):
                if extracted[v] is None:
                    extracted[v] = a
                elif v == "Additional Details":
                    # Append multiple Additional Details if present
                    extracted[v] += " | " + a
        i += 2

    return pd.Series(extracted)

# Apply the function to your DataFrame
result_df = Data['Que/Ans'].apply(extract_answers)
# Clean encoding artifacts (like Â, â€¦, etc.)
result_df = result_df.replace({r'[^\x00-\x7F]+': ''}, regex=True)

# Preview the cleaned DataFrame
result_df.head()
# Out:
#   Have you used business consulting services before?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#              How long has the business been running?  \
# 0                           Start-up/not started yet
# 1                           Start-up/not started yet
# 2  20  What is the business&#039;s annual turnove...
# 3  Less than 1 year  What is the business&#039;s ...
# 4  5 years or more  What is the business&#039;s a...
#
#   What is the business annual turnover/sales? How many employees do you have?  \
# 0                                        None                            None
# 1                                        None                            None
# 2                                        None                      25 or more
# 3                                        None                            None
# 4                                        None                         10 - 24
#
#   What industry is your business in?  \
# 0                           Services
# 1                           Services
# 2              Retail/consumer goods
# 3              Online Video Producer
# 4                       Construction
#
#   Which type(s) of consulting are you interested in?  \
# 0                                          Mentoring
# 1                                   Company strategy
# 2                                             extand
# 3                             Finance &amp; planning
# 4                             Finance &amp; planning
#
#                What are your goals for this service?  \
# 0             Clarification on start-up requirements
# 1  Increase marketing ROI, Increase sales/lead ge...
# 2                                    Business growth
# 3              Streamlined operations/administration
# 4             Cost reduction/efficiency improvements
#
#   How long do you need a consultant?  \
# 0                       I'm not sure
# 1                       I'm not sure
# 2                 Over several weeks
# 3                       I'm not sure
# 4                       I'm not sure
#
#      How would you like to work with the consultant?
# 0                                             Onsite
# 1  Remotely  Additional details Quality  Addition...
# 2  Onsite  Additional details we want to expand o...
# 3  Remotely  Additional details Hi! I&#039;m Leo....
# 4  I would like to discuss this with the pro  Add...

# %%
Data = pd.concat([Data, result_df], axis=1)

# %%
columns_to_drop = [
    'Time','Que/Ans','Category','Additional Details'
]

# Drop the columns (if they exist in the DataFrame)
Data = Data.drop(columns=[col for col in columns_to_drop if col in Data.columns])

pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', None)   # Show all rows


df = pd.DataFrame(Data)
df.to_csv('../data/sample_data_for_prediction_business_consulting.csv', index=False)

df
# Out:
#                        Location  Urgent  High  Verified  Additional  Frequent  \
# 0      Kegworth, Leicestershire       0     0         1           1         0
# 1                   London, TW9       1     0         1           1         0
# 2                   London, KT3       1     0         0           1         0
# 3                Sheffield, S13       1     0         1           1         0
# 4                  Cobham, KT11       0     0         1           1         1
# ..                          ...     ...   ...       ...         ...       ...
# 382  Kensington, Greater London       0     0         1           0         1
# 383              , Wembley, HA9       1     0         1           1         0
# 384            Broxbourne, EN10       0     0         0           0         1
# 385              Rotherham, S65       0     0         1           0         0
# 386      , Great Shelford, CB22       1     0         1           1         0
#
#     Have you used business consulting services before?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 382                                                 No
# 383                                                 No
# 384                                                 No
# 385                                                 No
# 386                                                 No
#
#                How long has the business been running?  \
# 0                             Start-up/not started yet
# 1                             Start-up/not started yet
# 2    20  What is the business&#039;s annual turnove...
# 3    Less than 1 year  What is the business&#039;s ...
# 4    5 years or more  What is the business&#039;s a...
# ..                                                 ...
# 382                           Start-up/not started yet
# 383                           Start-up/not started yet
# 384  all  What is the business&#039;s annual turnov...
# 385                           Start-up/not started yet
# 386  5 years or more  What is the business&#039;s a...
#
#     What is the business annual turnover/sales?  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# ..                                          ...
# 382                                        None
# 383                                        None
# 384                                        None
# 385                                        None
# 386                                        None
#
#     How many employees do you have? What industry is your business in?  \
# 0                              None                           Services
# 1                              None                           Services
# 2                        25 or more              Retail/consumer goods
# 3                              None              Online Video Producer
# 4                           10 - 24                       Construction
# ..                              ...                                ...
# 382                            None                    Restaurant/food
# 383                            None                          ecommerce
# 384                           1 - 4                           Services
# 385                            None                       Dog grooming
# 386                            None              Retail/consumer goods
#
#     Which type(s) of consulting are you interested in?  \
# 0                                            Mentoring
# 1                                     Company strategy
# 2                                               extand
# 3                               Finance &amp; planning
# 4                               Finance &amp; planning
# ..                                                 ...
# 382  Business plans, Company strategy, Finance &amp...
# 383  Business plans, Market research &amp; surveys,...
# 384  Business plans, Company strategy, Finance &amp...
# 385                                     Help to set up
# 386                   Whether to buy existing business
#
#                  What are your goals for this service?  \
# 0               Clarification on start-up requirements
# 1    Increase marketing ROI, Increase sales/lead ge...
# 2                                      Business growth
# 3                Streamlined operations/administration
# 4               Cost reduction/efficiency improvements
# ..                                                 ...
# 382    Business growth, Increase sales/lead generation
# 383                     Increase sales/lead generation
# 384  Business growth, Cost reduction/efficiency imp...
# 385                                    Business growth
# 386                                    Business growth
#
#             How long do you need a consultant?  \
# 0                                 I'm not sure
# 1                                 I'm not sure
# 2                           Over several weeks
# 3                                 I'm not sure
# 4                                 I'm not sure
# ..                                         ...
# 382                               I'm not sure
# 383                     For ongoing engagement
# 384                               I'm not sure
# 385                               I'm not sure
# 386  I would like to discuss this with the pro
#
#        How would you like to work with the consultant?
# 0                                               Onsite
# 1    Remotely  Additional details Quality  Addition...
# 2    Onsite  Additional details we want to expand o...
# 3    Remotely  Additional details Hi! I&#039;m Leo....
# 4    I would like to discuss this with the pro  Add...
# ..                                                 ...
# 382                                           Remotely
# 383  Remotely  Additional details WANT AN ECOMMERCE...
# 384          I would like to discuss this with the pro
# 385                                             Onsite
# 386  Remotely  Additional details I am considering ...
#
# [387 rows x 15 columns]
